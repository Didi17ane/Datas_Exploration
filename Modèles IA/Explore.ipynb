# %% [markdown]
# # **MISE EN SITUATION**

# %% [markdown]
# # **RECUPERATION DES DONNEES**

# %%
#importation des bibliothèques

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../DATAS/ALL_EHCVM.csv")

# %%
df.head()
# Out:
#    idmen  idind              region      sexe              mstat  \
# 0      2      4  AUTONOME D'ABIDJAN   Féminin        Célibataire
# 1      2      5  AUTONOME D'ABIDJAN   Féminin        Célibataire
# 2      2      3  AUTONOME D'ABIDJAN  Masculin        Célibataire
# 3      2      6  AUTONOME D'ABIDJAN   Féminin        Célibataire
# 4      2      2  AUTONOME D'ABIDJAN   Féminin  Marié(e) monogame
#
#           branch                            sectins  \
# 0  Aut. services  Entreprise publique/ parapublique
# 1            NaN                                NaN
# 2            NaN                                NaN
# 3            NaN                                NaN
# 4            NaN                                NaN
#
#                              csp  rev_total_mois  log_revenu  sans_revenu  \
# 0  Cadre moyen/agent de maîtrise        279244.0   12.539845            0
# 1                            NaN             0.0    0.000000            1
# 2                            NaN             0.0    0.000000            1
# 3                            NaN             0.0    0.000000            1
# 4                            NaN             0.0    0.000000            1
#
#   age_grp  age_num  empl_formel  bancarise  a_assurance      logem
# 0   25-34       29            1          1            0  Locataire
# 1    0-17       17            0          0            0  Locataire
# 2    0-17       15            0          0            0  Locataire
# 3    0-17       12            0          0            0  Locataire
# 4   25-34       34            0          0            0  Locataire

# %% [markdown]
# # **DESCRIPTION ET OBJECTIFS**

# %% [markdown]
# # **ANALYSE EXPLORATOIRE DES DONNEES**

# %%
# Copy du dataframe

df_ehcvm = df.copy()

# %%
df_ehcvm
# Out:
#        idmen  idind              region      sexe              mstat  \
# 0          2      4  AUTONOME D'ABIDJAN   Féminin        Célibataire
# 1          2      5  AUTONOME D'ABIDJAN   Féminin        Célibataire
# 2          2      3  AUTONOME D'ABIDJAN  Masculin        Célibataire
# 3          2      6  AUTONOME D'ABIDJAN   Féminin        Célibataire
# 4          2      2  AUTONOME D'ABIDJAN   Féminin  Marié(e) monogame
# ...      ...    ...                 ...       ...                ...
# 64486  13863  64490             MORONOU  Masculin        Célibataire
# 64487  13863  64489             MORONOU  Masculin        Célibataire
# 64488  13863  64491             MORONOU  Masculin        Célibataire
# 64489  13863  64488             MORONOU  Masculin        Célibataire
# 64490  13863  64486             MORONOU  Masculin  Marié(e) monogame
#
#                    branch                            sectins  \
# 0           Aut. services  Entreprise publique/ parapublique
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
# ...                   ...                                ...
# 64486                 NaN                                NaN
# 64487                 NaN                                NaN
# 64488                 NaN                                NaN
# 64489                 NaN                                NaN
# 64490  Elevage/syl./peche                  Entreprise Privée
#
#                                   csp  rev_total_mois  log_revenu  \
# 0       Cadre moyen/agent de maîtrise        279244.0   12.539845
# 1                                 NaN             0.0    0.000000
# 2                                 NaN             0.0    0.000000
# 3                                 NaN             0.0    0.000000
# 4                                 NaN             0.0    0.000000
# ...                               ...             ...         ...
# 64486                             NaN             0.0    0.000000
# 64487                             NaN             0.0    0.000000
# 64488                             NaN             0.0    0.000000
# 64489                             NaN             0.0    0.000000
# 64490  Travailleur pour compte propre             0.0    0.000000
#
#        sans_revenu age_grp  age_num  empl_formel  bancarise  a_assurance  \
# 0                0   25-34       29            1          1            0
# 1                1    0-17       17            0          0            0
# 2                1    0-17       15            0          0            0
# 3                1    0-17       12            0          0            0
# 4                1   25-34       34            0          0            0
# ...            ...     ...      ...          ...        ...          ...
# 64486            1    0-17       11            0          0            0
# 64487            1    0-17        7            0          0            0
# 64488            1    0-17       10            0          0            0
# 64489            1    0-17        4            0          0            0
# 64490            1   35-44       36            0          1            0
#
#                     logem
# 0               Locataire
# 1               Locataire
# 2               Locataire
# 3               Locataire
# 4               Locataire
# ...                   ...
# 64486  Proprietaire titre
# 64487  Proprietaire titre
# 64488  Proprietaire titre
# 64489  Proprietaire titre
# 64490  Proprietaire titre
#
# [64491 rows x 17 columns]

# %%
df_ehcvm.isna().sum()
# Out:
# idmen                 0
# idind                 0
# region                0
# sexe                  0
# mstat                 0
# branch            38197
# sectins           38197
# csp               38197
# rev_total_mois        0
# log_revenu            0
# sans_revenu           0
# age_grp               0
# age_num               0
# empl_formel           0
# bancarise             0
# a_assurance           0
# logem                 0
# dtype: int64

# %%
df_ehcvm.nunique()
# Out:
# idmen        12965
# idind        64491
# region          33
# sexe             2
# mstat            7
#              ...
# 41350.684        1
# 88999.898        1
# 229745.0         1
# 70514.75         1
# 59402.672        1
# Length: 1398, dtype: int64

# %%
listes = sorted(df_ehcvm["rev_total_mois"].unique().tolist())
df_listes = pd.DataFrame(listes, columns=["rev_total_mois_unique"])

# Exporter en CSV
df_listes.to_csv("revenus_uniques.csv", index=False, encoding="utf-8")

# %%
df_e = df_ehcvm[df_ehcvm["rev_total_mois"] == df_ehcvm["rev_total_mois"].max()]
df_e
# Out:
#       idmen  idind              region      sexe              mstat  \
# 2431    602   2430  AUTONOME D'ABIDJAN  Masculin  Marié(e) monogame
#
#                branch                            sectins              csp  \
# 2431  Education/Sante  Entreprise publique/ parapublique  Cadre supérieur
#
#       rev_total_mois  log_revenu  ...   227776.0  55166.668  58431.934  \
# 2431       2522333.3   14.740695  ...  2522333.3  2522333.3  2522333.3
#
#        34270.23   38675.59  41350.684  88999.898   229745.0   70514.75  \
# 2431  2522333.3  2522333.3  2522333.3  2522333.3  2522333.3  2522333.3
#
#       59402.672
# 2431  2522333.3
#
# [1 rows x 1398 columns]

# %% [markdown]
# # **NETTOYAGE DES DONNEES**

# %% [markdown]
# # **VISUALISATIONS DES DONNEES**

# %% [markdown]
# # **RESUME**
